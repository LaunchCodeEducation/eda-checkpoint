# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset:
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from itertools import groupby

df1 = pd.read_csv("Scorecard-Elements.csv")
df2 = pd.read_csv("NSLDS-Elements.csv")
# Out:
# C:\Users\Julie\AppData\Local\Temp\ipykernel_21628\3940674118.py:8: DtypeWarning: Columns (735,736,737,738,739,740,742,743,744,746,748,749,750,751,752,753,755,757,761,763,764,765,766,774,776,777,778,779,787,788,789,790,791,792,800,801,802,803,804,805,813,814,816,817,818,822,826,827,829,830,831,835,839,840,841,842,843,844,847,848,852,853,854,855,856,857,860,861,874,887,891,892,893,894,895,896,898,899,900,904,905,906,907,908,909,911,912,913,944,945,946,947,948,949,950,951,952,953,954,955,956,957,958,959,960,961,962,963,964,965,966,967,968,969,970,971,972,976,990,992,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1068,1082,1094,1095,1097,1102,1105,1106,1107,1111,1140,1141,1142,1143,1144,1145,1146,1147,1148,1149,1150,1151,1152,1153,1154,1155,1156,1157,1158,1159,1160,1161,1162,1163,1164,1165,1166,1167,1169,1170,1171,1172,1175,1176,1177) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("NSLDS-Elements.csv")

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
# I have 2 dataframes to review. I will look at each one seperately to get a better idea of how they connect

#Scorecard-Elements Date

# Dataframe work 
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7703 entries, 0 to 7702
# Columns: 123 entries, index to C150_4_POOLED_SUPP
# dtypes: float64(103), int64(8), object(12)
# memory usage: 7.2+ MB

# %%
# show the first ten rows
df1.head(10)
# Out:
#    index  UNITID    OPEID  OPEID6                               INSTNM  \
# 0      0  100654   100200    1002             Alabama A & M University
# 1      1  100663   105200    1052  University of Alabama at Birmingham
# 2      2  100690  2503400   25034                   Amridge University
# 3      3  100706   105500    1055  University of Alabama in Huntsville
# 4      4  100724   100500    1005             Alabama State University
# 5      5  100751   105100    1051            The University of Alabama
# 6      6  100760   100700    1007    Central Alabama Community College
# 7      7  100812   100800    1008              Athens State University
# 8      8  100830   831000    8310      Auburn University at Montgomery
# 9      9  100858   100900    1009                    Auburn University
#
#              CITY STABBR                    INSTURL  \
# 0          Normal     AL              www.aamu.edu/
# 1      Birmingham     AL                www.uab.edu
# ...

# %%
# check how many rows and columns 
df1.shape
# Out:
# (7703, 123)

# %%
# view column names
df1.columns
# Out:
# Index(['index', 'UNITID', 'OPEID', 'OPEID6', 'INSTNM', 'CITY', 'STABBR',
#        'INSTURL', 'NPCURL', 'HCM2',
#        ...
#        'RET_PTL4', 'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GT_25K_P6',
#        'GRAD_DEBT_MDN_SUPP', 'GRAD_DEBT_MDN10YR_SUPP', 'RPY_3YR_RT_SUPP',
#        'C150_L4_POOLED_SUPP', 'C150_4_POOLED_SUPP'],
#       dtype='object', length=123)

# %%
# view null counts
df1.isnull().sum()
# Out:
# index                        0
# UNITID                       0
# OPEID                        0
# OPEID6                       0
# INSTNM                       0
#                           ...
# GRAD_DEBT_MDN_SUPP          32
# GRAD_DEBT_MDN10YR_SUPP      32
# RPY_3YR_RT_SUPP            902
# C150_L4_POOLED_SUPP       3731
# C150_4_POOLED_SUPP        5206
# Length: 123, dtype: int64

# %%
#Looking at statistical summart of values 
df1.describe()
# Out:
#              index        UNITID         OPEID        OPEID6         HCM2  \
# count  7703.000000  7.703000e+03  7.703000e+03   7703.000000  7703.000000
# mean   3851.000000  1.663052e+06  1.891630e+06  16293.906530     0.030637
# std    2223.808895  6.566910e+06  3.383134e+06  13883.577507     0.172344
# min       0.000000  1.006540e+05  1.002000e+05   1002.000000     0.000000
# 25%    1925.500000  1.742420e+05  3.440500e+05   3436.500000     0.000000
# 50%    3851.000000  2.304720e+05  1.054211e+06  10490.000000     0.000000
# 75%    5776.500000  4.476520e+05  2.811950e+06  25988.000000     0.000000
# max    7702.000000  4.841450e+07  8.209882e+07  42371.000000     1.000000
#
#            PREDDEG      CONTROL       LOCALE         HBCU          PBI  ...  \
# count  7703.000000  7703.000000  7282.000000  7282.000000  7282.000000  ...
# mean      1.799688     2.215371    19.620434     0.014282     0.013046  ...
# ...

# %%
#Reviewing the number of unique entries
df1.nunique()
# Out:
# index                     7703
# UNITID                    7703
# OPEID                     7674
# OPEID6                    5662
# INSTNM                    7535
#                           ...
# GRAD_DEBT_MDN_SUPP        2060
# GRAD_DEBT_MDN10YR_SUPP    2060
# RPY_3YR_RT_SUPP           3962
# C150_L4_POOLED_SUPP       3742
# C150_4_POOLED_SUPP        2377
# Length: 123, dtype: int64

# %%
#Reviewing how many Missouri universities contain entries
df1['STABBR'].value_counts()['MO']
# Out:
# 200

# %%
#Reviewing the value counts for Grad debt specifically
df1['GRAD_DEBT_MDN_SUPP'].value_counts()
# Out:
# PrivacySuppressed    1545
# 9500                  536
# 27000                 315
# 25827.5               142
# 25000                 125
#                      ...
# 12400                   1
# 8443.5                  1
# 9604                    1
# 19262                   1
# 11061                   1
# Name: GRAD_DEBT_MDN_SUPP, Length: 2060, dtype: int64

# %%
#Reviwing earnings of students post-graduation
df1['MD_EARN_WNE_P10'].value_counts()
# Out:
# PrivacySuppressed    841
# 38800                157
# 21500                 97
# 49200                 78
# 27400                 46
#                     ...
# 84000                  1
# 66900                  1
# 52800                  1
# 67800                  1
# 186500                 1
# Name: MD_EARN_WNE_P10, Length: 598, dtype: int64

# %%
#Reviewing MO stats
df1.groupby(["STABBR"])["MO"].count()
# Out:
# STABBR
# AK     10
# AL     97
# AR     89
# AS      1
# AZ    134
# CA    795
# CO    129
# CT    102
# DC     26
# DE     19
# FL    446
# FM      1
# GA    186
# GU      3
# HI     26
# IA     92
# ID     42
# IL    305
# IN    162
# KS    103
# KY    110
# LA    124
# MA    200
# MD    101
# ME     44
# MH      1
# MI    209
# MN    157
# MO    200
# MP      1
# MS     65
# MT     32
# NC    210
# ND     30
# NE     50
# NH     42
# NJ    165
# NM     52
# NV     46
# NY    467
# OH    355
# OK    150
# OR     95
# PA    405
# PR    151
# PW      1
# RI     26
# SC    113
# SD     31
# TN    186
# TX    485
# UT     83
# VA    190
# VI      2
# VT     28
# WA    127
# WI    116
# WV     74
# WY     11
# Name: MO, dtype: int64

# %%
#Reviewing average grade debt
df1['GRAD_DEBT_MDN_SUPP'].value_counts()
# Out:
# PrivacySuppressed    1545
# 9500                  536
# 27000                 315
# 25827.5               142
# 25000                 125
#                      ...
# 12400                   1
# 8443.5                  1
# 9604                    1
# 19262                   1
# 11061                   1
# Name: GRAD_DEBT_MDN_SUPP, Length: 2060, dtype: int64

# %%
#Now I am reviewing my second dataset

#NSLDS-Elements

#Dataframe work
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7703 entries, 0 to 7702
# Columns: 1196 entries, index to NOTFIRSTGEN_RPY_3YR_RT_SUPP
# dtypes: float64(1), int64(4), object(1191)
# memory usage: 70.3+ MB

# %%
# show the first ten rows
df2.head(10)
# Out:
#    index  UNITID    OPEID  OPEID6                               INSTNM  \
# 0      0  100654   100200    1002             Alabama A & M University
# 1      1  100663   105200    1052  University of Alabama at Birmingham
# 2      2  100690  2503400   25034                   Amridge University
# 3      3  100706   105500    1055  University of Alabama in Huntsville
# 4      4  100724   100500    1005             Alabama State University
# 5      5  100751   105100    1051            The University of Alabama
# 6      6  100760   100700    1007    Central Alabama Community College
# 7      7  100812   100800    1008              Athens State University
# 8      8  100830   831000    8310      Auburn University at Montgomery
# 9      9  100858   100900    1009                    Auburn University
#
#    SCH_DEG       DEATH_YR2_RT COMP_ORIG_YR2_RT COMP_4YR_TRANS_YR2_RT  \
# 0      3.0  PrivacySuppressed      0.034926471     PrivacySuppressed
# ...

# %%
# check how many rows and columns 
df2.shape
# Out:
# (7703, 1196)

# %%
# view column names
df2.columns
# Out:
# Index(['index', 'UNITID', 'OPEID', 'OPEID6', 'INSTNM', 'SCH_DEG',
#        'DEATH_YR2_RT', 'COMP_ORIG_YR2_RT', 'COMP_4YR_TRANS_YR2_RT',
#        'COMP_2YR_TRANS_YR2_RT',
#        ...
#        'COMPL_RPY_3YR_RT_SUPP', 'NONCOM_RPY_3YR_RT_SUPP',
#        'DEP_RPY_3YR_RT_SUPP', 'IND_RPY_3YR_RT_SUPP', 'PELL_RPY_3YR_RT_SUPP',
#        'NOPELL_RPY_3YR_RT_SUPP', 'FEMALE_RPY_3YR_RT_SUPP',
#        'MALE_RPY_3YR_RT_SUPP', 'FIRSTGEN_RPY_3YR_RT_SUPP',
#        'NOTFIRSTGEN_RPY_3YR_RT_SUPP'],
#       dtype='object', length=1196)

# %%
# view null counts
df2.isnull().sum()
# Out:
# index                            0
# UNITID                           0
# OPEID                            0
# OPEID6                           0
# INSTNM                           0
#                               ...
# NOPELL_RPY_3YR_RT_SUPP         902
# FEMALE_RPY_3YR_RT_SUPP         902
# MALE_RPY_3YR_RT_SUPP           902
# FIRSTGEN_RPY_3YR_RT_SUPP       902
# NOTFIRSTGEN_RPY_3YR_RT_SUPP    902
# Length: 1196, dtype: int64

# %%
#Looking at statistical summary of values
df2.describe()
# Out:
#              index        UNITID         OPEID        OPEID6      SCH_DEG
# count  7703.000000  7.703000e+03  7.703000e+03   7703.000000  7404.000000
# mean   3851.000000  1.663052e+06  1.891630e+06  16293.906530     1.886818
# std    2223.808895  6.566910e+06  3.383134e+06  13883.577507     0.877407
# min       0.000000  1.006540e+05  1.002000e+05   1002.000000     1.000000
# 25%    1925.500000  1.742420e+05  3.440500e+05   3436.500000     1.000000
# 50%    3851.000000  2.304720e+05  1.054211e+06  10490.000000     2.000000
# 75%    5776.500000  4.476520e+05  2.811950e+06  25988.000000     3.000000
# max    7702.000000  4.841450e+07  8.209882e+07  42371.000000     3.000000

# %%
#Reviewing the number of unique entries
df2.nunique()
# Out:
# index                          7703
# UNITID                         7703
# OPEID                          7674
# OPEID6                         5662
# INSTNM                         7535
#                                ...
# NOPELL_RPY_3YR_RT_SUPP         2872
# FEMALE_RPY_3YR_RT_SUPP         3041
# MALE_RPY_3YR_RT_SUPP           2901
# FIRSTGEN_RPY_3YR_RT_SUPP       3321
# NOTFIRSTGEN_RPY_3YR_RT_SUPP    3419
# Length: 1196, dtype: int64

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
#Creating the scatter plot
plt.scatter(df1['STABBR'],df1['GRAD_DEBT_MDN_SUPP'],alpha=0.5 )
#Adding the aesthetics
plt.title('States to Graduate Debt Amount')
plt.xlabel('State')
plt.ylabel('Graduate Debt Amount in dollars') 
#Show the plot
plt.show()


# show the distribution of state universities
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# ...

# %%
df1['GRAD_DEBT_MDN_SUPP'].value_counts().plot();

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset? I was surprised that there were 200 MO universities listed. Also, I was suprised about the number of "PrivacySuppressed" data in D2 dataset. 1545 entries contained that word, which seems large. Also, a lot of my data was too large to run. Once I clean up the data, I will be able to run more graphs/charts.
# 2. Do you have any concerns about your dataset? I'm concerned about grouping the second dataset. There is a lot of information contained in the document. But, I think I can combine the "pell grants" into one column "no loans" into one column ... etc. Right now each of those terms individual has about 13 columns and if I combine/group them into one category, it will simplify the data greatly.
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data? I am going to group the MO schools. The 2nd dataset doesn't split the schools by states, it only provides the university names. I will need to join the 200 schools(univerisities) OPEID. The first data set, I want to review the columns state abb., school name, graduate earnings, and loan debt. I will compare that with the 2nd larger dataset of the school name and the different types of loan/debt columns.
